# %%
import geopandas as gpd

# %%
df = gpd.read_file('../data/Base_SUN_2018.csv')
df
# Out:
#      CVE_ENT              NOM_ENT CVE_MUN                       NOM_MUN  \
# 0         01       Aguascalientes   01011     San Francisco de los Romo
# 1         01       Aguascalientes   01005                   Jes�s Mar�a
# 2         01       Aguascalientes   01001                Aguascalientes
# 3         02      Baja California   02005            Playas de Rosarito
# 4         02      Baja California   02003                        Tecate
# ...      ...                  ...     ...                           ...
# 1084      32            Zacatecas   32039                    R�o Grande
# 1085      32            Zacatecas   32039                    R�o Grande
# 1086      32            Zacatecas   32042                    Sombrerete
# 1087      32            Zacatecas   32048  Tlaltenango de S�nchez Rom�n
# 1088      16  Michoac�n de Ocampo   16052               L�zaro C�rdenas
#
#         CVE_LOC                       NOM_LOC CVE_SUN  \
# ...
