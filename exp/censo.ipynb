# %%
import geopandas as gpd
import pandas as pd

# %%
censo_data = gpd.read_file('../data/ITER_NALTXT90.csv', sep='\t', encoding='latin-1')
censo_data
# Out:
#        entidad         nom_ent  mun                             nom_mun   loc  \
# 0           00  Total nacional  000                      Total nacional  0000
# 1           00  Total nacional  000                      Total nacional  9998
# 2           00  Total nacional  000                      Total nacional  9999
# 3           01  Aguascalientes  000  Total de la entidad Aguascalientes  0000
# 4           01  Aguascalientes  000  Total de la entidad Aguascalientes  9998
# ...        ...             ...  ...                                 ...   ...
# 162191      32       Zacatecas  056                           Zacatecas  0111
# 162192      32       Zacatecas  056                           Zacatecas  0112
# 162193      32       Zacatecas  056                           Zacatecas  0113
# 162194      32       Zacatecas  056                           Zacatecas  9998
# 162195      32       Zacatecas  056                           Zacatecas  9999
#
# ...
